# %%
import pandas as pd

df = pd.read_csv("data.csv")

df.head()
# Out:
#          date   week_day   hour       ticket_number  waiter  \
# 0  11/13/2024  Wednesday  16:55  FCB 0003-000024735       0
# 1  11/13/2024  Wednesday  16:55  FCB 0003-000024735       0
# 2   10/4/2024     Friday  11:31  FCA 0003-000000038      51
# 3   10/4/2024     Friday  14:00  FCA 0003-000000043      51
# 4   10/4/2024     Friday  14:00  FCA 0003-000000043      51
#
#                  product_name  quantity  unitary_price   total
# 0      Alfajor Super DDL x un       1.0           2700    2700
# 1   Alfajor Sin Azucar Suelto       1.0           2700    2700
# 2      Conito choc caja x12un      19.0          15675  297825
# 3    Alfajor Sin Azucar x9 Un       1.0          22500   22500
# 4  Alfajor 70 cacao caja x9un       1.0          22500   22500

# %%
# get most sold products on Friday
df[df["week_day"] == "Friday"].groupby("product_name").sum().sort_values("quantity", ascending=False).head(5)
# Out:
#                                                                             date  \
# product_name
# Alfajor Sin Azucar Suelto      10/4/202410/4/202410/4/202410/4/202410/4/20241...
# Alf. 150 aniv. Suelto          10/4/202410/4/202410/4/202410/4/202410/4/20241...
# Alfajor choc blanco nuez x un  10/4/202410/4/202410/4/202410/18/202410/18/202...
# Alfajor choc x un              10/4/202410/4/202410/4/202410/4/202410/4/20241...
# Alfajor merengue x un          10/4/202410/18/202410/18/202410/18/202410/18/2...
#
#                                                                         week_day  \
# product_name
# Alfajor Sin Azucar Suelto      FridayFridayFridayFridayFridayFridayFridayFrid...
# Alf. 150 aniv. Suelto          FridayFridayFridayFridayFridayFridayFridayFrid...
# Alfajor choc blanco nuez x un  FridayFridayFridayFridayFridayFridayFridayFrid...
# Alfajor choc x un              FridayFridayFridayFridayFridayFridayFridayFrid...
# ...
